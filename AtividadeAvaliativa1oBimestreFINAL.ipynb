# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoPauloSampaio/labs/blob/master/AtividadeAvaliativa1oBimestreFINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade avaliativa
#
# Leia atentamente as instruções de cada questão, e responda completamente.
#
# Para o inicio da atividade, execute o seguinte trecho de código:

# %%
# !pip install requests

# %%
import matplotlib.pyplot as plt
from PIL import Image
from numpy import array
import numpy as np
import requests

from io import BytesIO

response = requests.get('https://homepages.cae.wisc.edu/~ece533/images/peppers.png')
img = Image.open(BytesIO(response.content)).convert()
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# A imagem carregada é uma imagem "clássica" no estudo de processamento de imagem e computação gráfica. Temos a imagem colorida, com isto, podemos começar nossa avaliação.

# %% [markdown]
# ## Atividade 01
#
# Escreva/Implemente o código que plota a imagem em tons de cinza e o histograma da imagem em tons de cinza.

# %%
#img = np.array(img)
#img = np.mean(img, axis=(2)) 
#plt.subplot(131) 
#plt.axis('off')
#plt.imshow(img)


img_np = np.array(img)
img_gray = np.mean(img_np, axis=2) 
plt.imshow(Image.fromarray(img_gray)) 
 
plt.figure(figsize=(20,4))
plt.subplot(131)
plt.hist(img_gray.ravel(),color='gray')
# Out:
# (array([12956., 12605., 16455., 34093., 61087., 40480., 43400., 25628.,
#         10023.,  5417.]),
#  array([  0.        ,  22.43333333,  44.86666667,  67.3       ,
#          89.73333333, 112.16666667, 134.6       , 157.03333333,
#         179.46666667, 201.9       , 224.33333333]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Atividade 02
#
# Escreva/Implemente o código que plota a imagem em preto e branco e o histograma da imagem em preto e branco.

# %%
img_pb[img_gray >= 127] = 255
img_pb[img_gray <= 127] = 0
plt.imshow(Image.fromarray(img_pb)) 

plt.figure(figsize=(20,4))
plt.subplot(131)
plt.hist(img_pb.ravel(),color='black')
# Out:
# (array([163238.,      0.,      0.,      0.,      0.,      0.,      0.,
#              0.,      0.,  98906.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Atividade 03
#
# Sobre os histogramas gerados nas atividade 1 e 2, o que podemos concluir? Responda no espaço abaixo.

# %% [markdown]
# Bom analisando os dois histogramas podemos ver claramente que no primeiro histograma (referente a imagem com tons de cinza) no valores horizontais temos colunas que vão desde o valor 0 ao 255 isso justifica justamente os tons da figura pois ao ir do valor 0 que é o preto até 255 que é branco ele cria esse "fade" na imagem assim gerando os tons, ja no segundo histograma podemos confirmar ainda mais isso pois ele possui apenas duas coluas uma no valor 0 outra no valor 255 afinal a imagem ou é preta ou branca, pois então sempre que olharmos para com histograma com tal binaridade concluimos que se trata de uma imagem preto e branco.

# %% [markdown]
# ## Atividade 04
#
# Gere duas imagens negativas, uma utilizando a imagem em preto e branco como base, e a outra a imagem em tons de cinza. Plote as imagem no final.

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
img_grayN = 255 - img_gray
plt.imshow(Image.fromarray(img_grayN)) 

plt.figure(figsize=(20,4))
plt.subplot(131)
img_pbN = 255 - img_pb
plt.imshow(Image.fromarray(img_pbN))

# %% [markdown]
# ## Atividade 05
#
# Baseado nas imagens acima, o que você destaca?

# %% [markdown]
# Bom ja nessas duas imagens podemos ver a inversão das cores quando comparadas com as imagens originais, por isso é gerado o negativo como foi pedido, podemos ver que se fosse gerado um histograma das imagens negativas seria um histograma literalmente espelhado das imgens originais com isso podemos ver a clara inverção dos valores.

# %% [markdown]
# ## Atividade 06
#
# Escreva um código que plote o histograma das 3 cores (RGB) separadas.

# %%
img_r_arr = np.array(img)
#histograma
plt.figure(figsize=(20,4))
red = img_r_arr[:,:,0]
green = img_r_arr[:,:,1]
blue = img_r_arr[:,:,2]

plt.subplot(131)
plt.hist(red.ravel(),color='red')

plt.subplot(132)
plt.hist(green.ravel(),color='green')

plt.subplot(133)
plt.hist(blue.ravel(),color='blue')
# Out:
# (array([34526., 66249., 44185., 61311., 27265.,  9008.,  5839.,  5756.,
#          5861.,  2144.]),
#  array([  0. ,  22.9,  45.8,  68.7,  91.6, 114.5, 137.4, 160.3, 183.2,
#         206.1, 229. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Baseado no histograma das 3 cores, escreva o que podemos concluir da imagem.

# %% [markdown]
# Analisando os 3 histogramas podemos constatar alguns fatos, por se tratar de uma imagem com cores verdes e vermelhas predominantes vemos um valor muito maior nos histogramas red e green na parte clara da imagem que serias entre 180 e 200 nos valores horizontais e ja que a imagem não possui um azul nitido vemos um valor muito baixo, Tambem podemos concluir que o azul se esconde nas partes mais escuras da imagem pois é a maior coluna de seu histograma, e por final que o ver faz a media de valores escuros e claro pois esta presente nos dois, se tornando assim verde a cor predominante da imagem.

# %% [markdown]
# ## Atividade 07
#
# Escreva um código que calcule a média dos pixels do canal azul, então, troque todos os valores do canal azul pela média e plote a nova imagem, em versão colorida.

# %%
medB = np.array(img)
blue = medB[:,:,2]
med = blue.mean()
medB[:,:,2] = med
plt.imshow(Image.fromarray(medB))

# %% [markdown]
# Explique como a imagem da questão 5 foi afetada?

# %% [markdown]
# A imagem em questão continuou colorida por assim dizer, mas teve uma clara mudança em seu tom de azul, queno caso foi diminuido nos pontos mais fortes assim dando uma aparencia amarelada para a imagem, nos pontos mais claros e escuros.
